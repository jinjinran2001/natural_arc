# %%
import json

# %%
# read json
with open('expanded_incremental_arc_dataset.json') as f:
    data = json.load(f)

# %%
example = data['train'][0]

# %%
def extract_programs(data):
    """Extract all programs from the data structure"""
    programs = []
    
    # Parse train example programs
    if 'subroutines' in data:
        for subroutine_key, subroutine in data['subroutines'].items():
            program = subroutine.get('program')
            if program:
                programs.append(f"{subroutine_key}: {program}")
    
    # Parse test example programs
    if 'test_subroutines' in data:
        for subroutine_key, subroutine in data['test_subroutines'].items():
            program = subroutine.get('program')
            if program:
                programs.append(f"{subroutine_key} (test): {program}")
    
    return programs

# %%
result = []
for data in data['train']:
    result.extend(extract_programs(data))

# %%
result
# Out:
# ['subroutine_0: replace(I, FIVE, ZERO)',
#  'subroutine_1: downscale(I, THREE)',
#  'subroutine_0 (test): replace(I, FIVE, ZERO)',
#  'subroutine_1 (test): downscale(I, THREE)',
#  'subroutine_0: bottomhalf(I)',
#  'subroutine_1: vconcat(hmirror(I), I)',
#  'subroutine_0 (test): bottomhalf(I)',
#  'subroutine_1 (test): vconcat(hmirror(I), I)',
#  'subroutine_0: bottomhalf(I)',
#  'subroutine_1: vconcat(hmirror(I), I)',
#  'subroutine_0 (test): bottomhalf(I)',
#  'subroutine_1 (test): vconcat(hmirror(I), I)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: hconcat(I, I)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): hconcat(I, I)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: hconcat(I, I)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): hconcat(I, I)',
#  'subroutine_0: hconcat(I, vmirror(I))',
#  'subroutine_1: vconcat(I, hmirror(I))',
#  'subroutine_0 (test): hconcat(I, vmirror(I))',
#  'subroutine_1 (test): vconcat(I, hmirror(I))',
#  'subroutine_0: hconcat(I, vmirror(I))',
#  'subroutine_1: vconcat(I, hmirror(I))',
#  'subroutine_0 (test): hconcat(I, vmirror(I))',
#  'subroutine_1 (test): vconcat(I, hmirror(I))',
#  'subroutine_0: hconcat(I, vmirror(I))',
#  'subroutine_1: vconcat(I, hmirror(I))',
#  'subroutine_0 (test): hconcat(I, vmirror(I))',
#  'subroutine_1 (test): vconcat(I, hmirror(I))',
#  'subroutine_0: hconcat(I, vmirror(I))',
#  'subroutine_1: vconcat(I, hmirror(I))',
#  'subroutine_0 (test): hconcat(I, vmirror(I))',
#  'subroutine_1 (test): vconcat(I, hmirror(I))',
#  'subroutine_0: subgrid(merge(objects(I, T, T, T)), I)',
#  'subroutine_1: replace(I, ONE, ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): replace(I, ONE, ZERO)',
#  'subroutine_0: move(I, first(objects(I, T, F, T)), DOWN)',
#  'subroutine_1: replace(I, EIGHT, TWO)',
#  'subroutine_0 (test): move(I, first(objects(I, T, F, T)), DOWN)',
#  'subroutine_1 (test): replace(I, EIGHT, TWO)',
#  'subroutine_0: rot270(I)',
#  'subroutine_1: rot90(apply(rbind(order, identity), I))',
#  'subroutine_0 (test): rot270(I)',
#  'subroutine_1 (test): rot90(apply(rbind(order, identity), I))',
#  'subroutine_0: switch(switch(I, THREE, FOUR), EIGHT, NINE)',
#  'subroutine_1: switch(switch(I, TWO, SIX), ONE, FIVE)',
#  'subroutine_0 (test): switch(switch(I, THREE, FOUR), EIGHT, NINE)',
#  'subroutine_1 (test): switch(switch(I, TWO, SIX), ONE, FIVE)',
#  'subroutine_0: switch(switch(I, THREE, FOUR), EIGHT, NINE)',
#  'subroutine_1: switch(I, TWO, SIX)',
#  'subroutine_2: switch(I, ONE, FIVE)',
#  'subroutine_0 (test): switch(switch(I, THREE, FOUR), EIGHT, NINE)',
#  'subroutine_1 (test): switch(I, TWO, SIX)',
#  'subroutine_2 (test): switch(I, ONE, FIVE)',
#  'subroutine_0: switch(I, THREE, FOUR)',
#  'subroutine_1: switch(switch(switch(I, EIGHT, NINE), TWO, SIX), ONE, FIVE)',
#  'subroutine_0 (test): switch(I, THREE, FOUR)',
#  'subroutine_1 (test): switch(switch(switch(I, EIGHT, NINE), TWO, SIX), ONE, FIVE)',
#  'subroutine_0: switch(I, THREE, FOUR)',
#  'subroutine_1: switch(switch(I, EIGHT, NINE), TWO, SIX)',
#  'subroutine_2: switch(I, ONE, FIVE)',
#  'subroutine_0 (test): switch(I, THREE, FOUR)',
#  'subroutine_1 (test): switch(switch(I, EIGHT, NINE), TWO, SIX)',
#  'subroutine_2 (test): switch(I, ONE, FIVE)',
#  'subroutine_0: switch(I, THREE, FOUR)',
#  'subroutine_1: switch(I, EIGHT, NINE)',
#  'subroutine_2: switch(switch(I, TWO, SIX), ONE, FIVE)',
#  'subroutine_0 (test): switch(I, THREE, FOUR)',
#  'subroutine_1 (test): switch(I, EIGHT, NINE)',
#  'subroutine_2 (test): switch(switch(I, TWO, SIX), ONE, FIVE)',
#  'subroutine_0: switch(I, THREE, FOUR)',
#  'subroutine_1: switch(I, EIGHT, NINE)',
#  'subroutine_2: switch(I, TWO, SIX)',
#  'subroutine_3: switch(I, ONE, FIVE)',
#  'subroutine_0 (test): switch(I, THREE, FOUR)',
#  'subroutine_1 (test): switch(I, EIGHT, NINE)',
#  'subroutine_2 (test): switch(I, TWO, SIX)',
#  'subroutine_3 (test): switch(I, ONE, FIVE)',
#  'subroutine_0: subgrid(argmax(objects(I, T, F, F), height), I)',
#  'subroutine_1: trim(I)',
#  'subroutine_0 (test): subgrid(argmax(objects(I, T, F, F), height), I)',
#  'subroutine_1 (test): trim(I)',
#  'subroutine_0: lefthalf(subgrid(first(objects(I, F, T, T)), I))',
#  'subroutine_1: tophalf(I)',
#  'subroutine_0 (test): lefthalf(subgrid(first(objects(I, F, T, T)), I))',
#  'subroutine_1 (test): tophalf(I)',
#  'subroutine_0: subgrid(first(objects(I, F, T, T)), I)',
#  'subroutine_1: tophalf(lefthalf(I))',
#  'subroutine_0 (test): subgrid(first(objects(I, F, T, T)), I)',
#  'subroutine_1 (test): tophalf(lefthalf(I))',
#  'subroutine_0: subgrid(first(objects(I, F, T, T)), I)',
#  'subroutine_1: lefthalf(I)',
#  'subroutine_2: tophalf(I)',
#  'subroutine_0 (test): subgrid(first(objects(I, F, T, T)), I)',
#  'subroutine_1 (test): lefthalf(I)',
#  'subroutine_2 (test): tophalf(I)',
#  'subroutine_0: switch(I, first(palette(I)), last(palette(I)))',
#  'subroutine_1: replace(I, FIVE, ZERO)',
#  'subroutine_0 (test): switch(I, first(palette(I)), last(palette(I)))',
#  'subroutine_1 (test): replace(I, FIVE, ZERO)',
#  'subroutine_0: fill(I, EIGHT, mapply(fork(connect, ulcorner, centerofmass), objects(I, T, F, T)))',
#  'subroutine_1: switch(I, EIGHT, TWO)',
#  'subroutine_0 (test): fill(I, EIGHT, mapply(fork(connect, ulcorner, centerofmass), objects(I, T, F, T)))',
#  'subroutine_1 (test): switch(I, EIGHT, TWO)',
#  'subroutine_0: cellwise(lefthalf(vmirror(I)), vmirror(righthalf(vmirror(I))), ZERO)',
#  'subroutine_1: replace(I, ONE, TWO)',
#  'subroutine_0 (test): cellwise(lefthalf(vmirror(I)), vmirror(righthalf(vmirror(I))), ZERO)',
#  'subroutine_1 (test): replace(I, ONE, TWO)',
#  'subroutine_0: subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1: switch(I, leastcolor(I), mostcolor(I))',
#  'subroutine_0 (test): subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1 (test): switch(I, leastcolor(I), mostcolor(I))',
#  'subroutine_0: subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1: switch(I, leastcolor(I), mostcolor(I))',
#  'subroutine_0 (test): subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1 (test): switch(I, leastcolor(I), mostcolor(I))',
#  'subroutine_0: subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1: switch(I, leastcolor(I), mostcolor(I))',
#  'subroutine_0 (test): subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1 (test): switch(I, leastcolor(I), mostcolor(I))',
#  'subroutine_0: canvas(ZERO, astuple(size(objects(I, T, F, T)), size(objects(I, T, F, T))))',
#  'subroutine_1: fill(I, EIGHT, shoot(ORIGIN, UNITY))',
#  'subroutine_0 (test): canvas(ZERO, astuple(size(objects(I, T, F, T)), size(objects(I, T, F, T))))',
#  'subroutine_1 (test): fill(I, EIGHT, shoot(ORIGIN, UNITY))',
#  'subroutine_0: hconcat(crop(I, ORIGIN, astuple(TWO, ONE)), hmirror(crop(I, ORIGIN, astuple(TWO, ONE))))',
#  'subroutine_1: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): hconcat(crop(I, ORIGIN, astuple(TWO, ONE)), hmirror(crop(I, ORIGIN, astuple(TWO, ONE))))',
#  'subroutine_1 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(I, hmirror(I))',
#  'subroutine_2: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(I, hmirror(I))',
#  'subroutine_2 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(I, hmirror(I))',
#  'subroutine_2: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(I, hmirror(I))',
#  'subroutine_2 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: hconcat(crop(I, ORIGIN, astuple(TWO, ONE)), hmirror(crop(I, ORIGIN, astuple(TWO, ONE))))',
#  'subroutine_1: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): hconcat(crop(I, ORIGIN, astuple(TWO, ONE)), hmirror(crop(I, ORIGIN, astuple(TWO, ONE))))',
#  'subroutine_1 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(I, hmirror(I))',
#  'subroutine_2: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(I, hmirror(I))',
#  'subroutine_2 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(I, hmirror(I))',
#  'subroutine_2: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(I, hmirror(I))',
#  'subroutine_2 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: hconcat(crop(I, ORIGIN, astuple(TWO, ONE)), hmirror(crop(I, ORIGIN, astuple(TWO, ONE))))',
#  'subroutine_1: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): hconcat(crop(I, ORIGIN, astuple(TWO, ONE)), hmirror(crop(I, ORIGIN, astuple(TWO, ONE))))',
#  'subroutine_1 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(I, hmirror(I))',
#  'subroutine_2: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(I, hmirror(I))',
#  'subroutine_2 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(hconcat(hconcat(I, hmirror(I)), hconcat(I, hmirror(I))), hconcat(I, hmirror(I)))',
#  'subroutine_0: crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1: hconcat(I, hmirror(I))',
#  'subroutine_2: hconcat(hconcat(I, I), I)',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(TWO, ONE))',
#  'subroutine_1 (test): hconcat(I, hmirror(I))',
#  'subroutine_2 (test): hconcat(hconcat(I, I), I)',
#  'subroutine_0: fill(I, TWO, mfilter(objects(I, T, F, F), compose(flip, rbind(bordering, I))))',
#  'subroutine_1: replace(I, ZERO, THREE)',
#  'subroutine_0 (test): fill(I, TWO, mfilter(objects(I, T, F, F), compose(flip, rbind(bordering, I))))',
#  'subroutine_1 (test): replace(I, ZERO, THREE)',
#  'subroutine_0: crop(I, ORIGIN, astuple(halve(height(I)), width(I)))',
#  'subroutine_1: vconcat(I, hmirror(I))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(halve(height(I)), width(I)))',
#  'subroutine_1 (test): vconcat(I, hmirror(I))',
#  'subroutine_0: crop(I, ORIGIN, astuple(halve(height(I)), width(I)))',
#  'subroutine_1: vconcat(I, hmirror(I))',
#  'subroutine_0 (test): crop(I, ORIGIN, astuple(halve(height(I)), width(I)))',
#  'subroutine_1 (test): vconcat(I, hmirror(I))',
#  'subroutine_0: rot90(dedupe(subgrid(first(objects(I, F, F, T)), I)))',
#  'subroutine_1: rot270(dedupe(I))',
#  'subroutine_0 (test): rot90(dedupe(subgrid(first(objects(I, F, F, T)), I)))',
#  'subroutine_1 (test): rot270(dedupe(I))',
#  'subroutine_0: subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1: rot270(dedupe(rot90(dedupe(I))))',
#  'subroutine_0 (test): subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1 (test): rot270(dedupe(rot90(dedupe(I))))',
#  'subroutine_0: subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1: rot90(dedupe(I))',
#  'subroutine_2: rot270(dedupe(I))',
#  'subroutine_0 (test): subgrid(first(objects(I, F, F, T)), I)',
#  'subroutine_1 (test): rot90(dedupe(I))',
#  'subroutine_2 (test): rot270(dedupe(I))',
#  'subroutine_0: vconcat(I, branch(equality(tophalf(I), bottomhalf(I)), bottomhalf(I), crop(I, TWO_BY_ZERO, THREE_BY_THREE)))',
#  'subroutine_1: replace(I, ONE, TWO)',
#  'subroutine_0 (test): vconcat(I, branch(equality(tophalf(I), bottomhalf(I)), bottomhalf(I), crop(I, TWO_BY_ZERO, THREE_BY_THREE)))',
#  'subroutine_1 (test): replace(I, ONE, TWO)',
#  'subroutine_0: fill(fill(I, THREE, merge(sizefilter(objects(I, T, F, T), ONE))), TWO, merge(sizefilter(objects(I, T, F, T), TWO)))',
#  'subroutine_1: replace(I, ZERO, ONE)',
#  'subroutine_0 (test): fill(fill(I, THREE, merge(sizefilter(objects(I, T, F, T), ONE))), TWO, merge(sizefilter(objects(I, T, F, T), TWO)))',
#  'subroutine_1 (test): replace(I, ZERO, ONE)',
#  'subroutine_0: replace(apply(lbind(apply, maximum), papply(pair, I, dmirror(I))), ZERO, mostcolor(apply(lbind(apply, maximum), papply(pair, I, dmirror(I)))))',
#  'subroutine_1: fill(I, index(I, ORIGIN), shoot(ORIGIN, UNITY))',
#  'subroutine_0 (test): replace(apply(lbind(apply, maximum), papply(pair, I, dmirror(I))), ZERO, mostcolor(apply(lbind(apply, maximum), papply(pair, I, dmirror(I)))))',
#  'subroutine_1 (test): fill(I, index(I, ORIGIN), shoot(ORIGIN, UNITY))',
#  'subroutine_0: replace(apply(lbind(apply, maximum), papply(pair, I, dmirror(I))), ZERO, mostcolor(apply(lbind(apply, maximum), papply(pair, I, dmirror(I)))))',
#  'subroutine_1: fill(I, index(I, ORIGIN), shoot(ORIGIN, UNITY))',
#  'subroutine_0 (test): replace(apply(lbind(apply, maximum), papply(pair, I, dmirror(I))), ZERO, mostcolor(apply(lbind(apply, maximum), papply(pair, I, dmirror(I)))))',
#  'subroutine_1 (test): fill(I, index(I, ORIGIN), shoot(ORIGIN, UNITY))',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0 (test): subgrid(merge(objects(I, T, F, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, chain(ineighbors, last, first)), objects(I, T, F, T)))',
#  'subroutine_1: vconcat(first(vsplit(I, THREE)), vconcat(first(vsplit(I, THREE)), first(vsplit(I, THREE))))',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, chain(ineighbors, last, first)), objects(I, T, F, T)))',
#  'subroutine_1 (test): vconcat(first(vsplit(I, THREE)), vconcat(first(vsplit(I, THREE)), first(vsplit(I, THREE))))',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, chain(ineighbors, last, first)), objects(I, T, F, T)))',
#  'subroutine_1: vconcat(first(vsplit(I, THREE)), vconcat(first(vsplit(I, THREE)), first(vsplit(I, THREE))))',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, chain(ineighbors, last, first)), objects(I, T, F, T)))',
#  'subroutine_1 (test): vconcat(first(vsplit(I, THREE)), vconcat(first(vsplit(I, THREE)), first(vsplit(I, THREE))))',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, chain(ineighbors, last, first)), objects(I, T, F, T)))',
#  'subroutine_1: vconcat(first(vsplit(I, THREE)), vconcat(first(vsplit(I, THREE)), first(vsplit(I, THREE))))',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, chain(ineighbors, last, first)), objects(I, T, F, T)))',
#  'subroutine_1 (test): vconcat(first(vsplit(I, THREE)), vconcat(first(vsplit(I, THREE)), first(vsplit(I, THREE))))',
#  'subroutine_0: paint(canvas(color(argmin(objects(rot270(I), T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(rot270(I), T, F, T), size)))',
#  'subroutine_1: rot90(I)',
#  'subroutine_0 (test): paint(canvas(color(argmin(objects(rot270(I), T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(rot270(I), T, F, T), size)))',
#  'subroutine_1 (test): rot90(I)',
#  'subroutine_0: rot270(I)',
#  'subroutine_1: rot90(paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size))))',
#  'subroutine_0 (test): rot270(I)',
#  'subroutine_1 (test): rot90(paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size))))',
#  'subroutine_0: rot270(I)',
#  'subroutine_1: paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size)))',
#  'subroutine_2: rot90(I)',
#  'subroutine_0 (test): rot270(I)',
#  'subroutine_1 (test): paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size)))',
#  'subroutine_2 (test): rot90(I)',
#  'subroutine_0: rot270(I)',
#  'subroutine_1: rot90(paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size))))',
#  'subroutine_0 (test): rot270(I)',
#  'subroutine_1 (test): rot90(paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size))))',
#  'subroutine_0: rot270(I)',
#  'subroutine_1: paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size)))',
#  'subroutine_2: rot90(I)',
#  'subroutine_0 (test): rot270(I)',
#  'subroutine_1 (test): paint(canvas(color(argmin(objects(I, T, F, T), size)), THREE_BY_THREE), normalize(argmax(objects(I, T, F, T), size)))',
#  'subroutine_2 (test): rot90(I)',
#  'subroutine_0: compress(I)',
#  'subroutine_1: crop(merge(apply(rbind(canvas, UNITY), order(palette(I), compose(invert, lbind(colorcount, I))))), DOWN, astuple(THREE, ONE))',
#  'subroutine_0 (test): compress(I)',
#  'subroutine_1 (test): crop(merge(apply(rbind(canvas, UNITY), order(palette(I), compose(invert, lbind(colorcount, I))))), DOWN, astuple(THREE, ONE))',
#  'subroutine_0: compress(I)',
#  'subroutine_1: crop(merge(apply(rbind(canvas, UNITY), order(palette(I), compose(invert, lbind(colorcount, I))))), DOWN, astuple(THREE, ONE))',
#  'subroutine_0 (test): compress(I)',
#  'subroutine_1 (test): crop(merge(apply(rbind(canvas, UNITY), order(palette(I), compose(invert, lbind(colorcount, I))))), DOWN, astuple(THREE, ONE))',
#  'subroutine_0: cellwise(upscale(subgrid(first(objects(I, T, T, T)), I), THREE), vconcat(vconcat(hconcat(hconcat(subgrid(first(objects(I, T, T, T)), I), subgrid(first(objects(I, T, T, T)), I)), subgrid(first(objects(I, T, T, T)), I)), hconcat(hconcat(subgrid(first(objects(I, T, T, T)), I), subgrid(first(objects(I, T, T, T)), I)), subgrid(first(objects(I, T, T, T)), I))), hconcat(hconcat(subgrid(first(objects(I, T, T, T)), I), subgrid(first(objects(I, T, T, T)), I)), subgrid(first(objects(I, T, T, T)), I))), ZERO)',
#  'subroutine_1: downscale(I, THREE)',
#  'subroutine_0 (test): cellwise(upscale(subgrid(first(objects(I, T, T, T)), I), THREE), vconcat(vconcat(hconcat(hconcat(subgrid(first(objects(I, T, T, T)), I), subgrid(first(objects(I, T, T, T)), I)), subgrid(first(objects(I, T, T, T)), I)), hconcat(hconcat(subgrid(first(objects(I, T, T, T)), I), subgrid(first(objects(I, T, T, T)), I)), subgrid(first(objects(I, T, T, T)), I))), hconcat(hconcat(subgrid(first(objects(I, T, T, T)), I), subgrid(first(objects(I, T, T, T)), I)), subgrid(first(objects(I, T, T, T)), I))), ZERO)',
#  'subroutine_1 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): downscale(cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO), THREE)',
#  'subroutine_0: subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1: cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): subgrid(first(objects(I, T, T, T)), I)',
#  'subroutine_1 (test): cellwise(upscale(I, THREE), vconcat(vconcat(hconcat(hconcat(I, I), I), hconcat(hconcat(I, I), I)), hconcat(hconcat(I, I), I)), ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1: replace(replace(replace(I, TWO, SEVEN), THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0 (test): replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1 (test): replace(replace(replace(I, TWO, SEVEN), THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0: replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1: replace(replace(I, TWO, SEVEN), THREE, EIGHT)',
#  'subroutine_2: replace(I, FOUR, NINE)',
#  'subroutine_0 (test): replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1 (test): replace(replace(I, TWO, SEVEN), THREE, EIGHT)',
#  'subroutine_2 (test): replace(I, FOUR, NINE)',
#  'subroutine_0: replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1: replace(I, TWO, SEVEN)',
#  'subroutine_2: replace(replace(I, THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0 (test): replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1 (test): replace(I, TWO, SEVEN)',
#  'subroutine_2 (test): replace(replace(I, THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0: replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1: replace(I, TWO, SEVEN)',
#  'subroutine_2: replace(I, THREE, EIGHT)',
#  'subroutine_3: replace(I, FOUR, NINE)',
#  'subroutine_0 (test): replace(paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE))), ONE, SIX)',
#  'subroutine_1 (test): replace(I, TWO, SEVEN)',
#  'subroutine_2 (test): replace(I, THREE, EIGHT)',
#  'subroutine_3 (test): replace(I, FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(replace(replace(replace(I, ONE, SIX), TWO, SEVEN), THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(replace(replace(replace(I, ONE, SIX), TWO, SEVEN), THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(replace(replace(I, ONE, SIX), TWO, SEVEN), THREE, EIGHT)',
#  'subroutine_2: replace(I, FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(replace(replace(I, ONE, SIX), TWO, SEVEN), THREE, EIGHT)',
#  'subroutine_2 (test): replace(I, FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(replace(I, ONE, SIX), TWO, SEVEN)',
#  'subroutine_2: replace(replace(I, THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(replace(I, ONE, SIX), TWO, SEVEN)',
#  'subroutine_2 (test): replace(replace(I, THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(replace(I, ONE, SIX), TWO, SEVEN)',
#  'subroutine_2: replace(I, THREE, EIGHT)',
#  'subroutine_3: replace(I, FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(replace(I, ONE, SIX), TWO, SEVEN)',
#  'subroutine_2 (test): replace(I, THREE, EIGHT)',
#  'subroutine_3 (test): replace(I, FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(I, ONE, SIX)',
#  'subroutine_2: replace(replace(replace(I, TWO, SEVEN), THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(I, ONE, SIX)',
#  'subroutine_2 (test): replace(replace(replace(I, TWO, SEVEN), THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(I, ONE, SIX)',
#  'subroutine_2: replace(replace(I, TWO, SEVEN), THREE, EIGHT)',
#  'subroutine_3: replace(I, FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(I, ONE, SIX)',
#  'subroutine_2 (test): replace(replace(I, TWO, SEVEN), THREE, EIGHT)',
#  'subroutine_3 (test): replace(I, FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(I, ONE, SIX)',
#  'subroutine_2: replace(I, TWO, SEVEN)',
#  'subroutine_3: replace(replace(I, THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(I, ONE, SIX)',
#  'subroutine_2 (test): replace(I, TWO, SEVEN)',
#  'subroutine_3 (test): replace(replace(I, THREE, EIGHT), FOUR, NINE)',
#  'subroutine_0: paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1: replace(I, ONE, SIX)',
#  'subroutine_2: replace(I, TWO, SEVEN)',
#  'subroutine_3: replace(I, THREE, EIGHT)',
#  'subroutine_4: replace(I, FOUR, NINE)',
#  'subroutine_0 (test): paint(I, mapply(fork(recolor, color, compose(neighbors, center)), sizefilter(objects(I, T, F, T), ONE)))',
#  'subroutine_1 (test): replace(I, ONE, SIX)',
#  'subroutine_2 (test): replace(I, TWO, SEVEN)',
#  'subroutine_3 (test): replace(I, THREE, EIGHT)',
#  'subroutine_4 (test): replace(I, FOUR, NINE)',
#  'subroutine_0: replace(replace(subgrid(argmax(objects(I, T, T, T), size), I), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)), ZERO), color(argmax(objects(I, T, T, T), size)), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)))',
#  'subroutine_1: downscale(I, divide(height(I), THREE))',
#  'subroutine_0 (test): replace(replace(subgrid(argmax(objects(I, T, T, T), size), I), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)), ZERO), color(argmax(objects(I, T, T, T), size)), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)))',
#  'subroutine_1 (test): downscale(I, divide(height(I), THREE))',
#  'subroutine_0: replace(replace(subgrid(argmax(objects(I, T, T, T), size), I), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)), ZERO), color(argmax(objects(I, T, T, T), size)), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)))',
#  'subroutine_1: downscale(I, divide(height(I), THREE))',
#  'subroutine_0 (test): replace(replace(subgrid(argmax(objects(I, T, T, T), size), I), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)), ZERO), color(argmax(objects(I, T, T, T), size)), leastcolor(subgrid(argmax(objects(I, T, T, T), size), I)))',
#  'subroutine_1 (test): downscale(I, divide(height(I), THREE))',
#  'subroutine_0: fill(underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline))), TWO, mapply(compose(backdrop, inbox), objects(underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline))), F, F, T)))',
#  'subroutine_1: replace(I, NEG_ONE, ZERO)',
#  'subroutine_0 (test): fill(underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline))), TWO, mapply(compose(backdrop, inbox), objects(underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline))), F, F, T)))',
#  'subroutine_1 (test): replace(I, NEG_ONE, ZERO)',
#  'subroutine_0: underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1: replace(fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T))), NEG_ONE, ZERO)',
#  'subroutine_0 (test): underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1 (test): replace(fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T))), NEG_ONE, ZERO)',
#  'subroutine_0: underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1: fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T)))',
#  'subroutine_2: replace(I, NEG_ONE, ZERO)',
#  'subroutine_0 (test): underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1 (test): fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T)))',
#  'subroutine_2 (test): replace(I, NEG_ONE, ZERO)',
#  'subroutine_0: underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1: replace(fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T))), NEG_ONE, ZERO)',
#  'subroutine_0 (test): underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1 (test): replace(fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T))), NEG_ONE, ZERO)',
#  'subroutine_0: underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1: fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T)))',
#  'subroutine_2: replace(I, NEG_ONE, ZERO)',
#  'subroutine_0 (test): underfill(I, NEG_ONE, mfilter(prapply(connect, ofcolor(I, FOUR), ofcolor(I, FOUR)), fork(either, vline, hline)))',
#  'subroutine_1 (test): fill(I, TWO, mapply(compose(backdrop, inbox), objects(I, F, F, T)))',
#  'subroutine_2 (test): replace(I, NEG_ONE, ZERO)',
#  'subroutine_0: paint(canvas(ZERO, shape(I)), mpapply(shift, apply(normalize, order(objects(I, T, F, T), compose(invert, size))), apply(toivec, interval(ZERO, size(apply(normalize, order(objects(I, T, F, T), compose(invert, size)))), ONE))))',
#  'subroutine_1: rot180(I)',
#  'subroutine_0 (test): paint(canvas(ZERO, shape(I)), mpapply(shift, apply(normalize, order(objects(I, T, F, T), compose(invert, size))), apply(toivec, interval(ZERO, size(apply(normalize, order(objects(I, T, F, T), compose(invert, size)))), ONE))))',
#  'subroutine_1 (test): rot180(I)',
#  'subroutine_0: replace(fill(compress(I), ONE, mfilter(apply(rbind(toobject, compress(I)), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO))), SIX, ZERO)',
#  'subroutine_1: downscale(I, THREE)',
#  'subroutine_0 (test): replace(fill(compress(I), ONE, mfilter(apply(rbind(toobject, compress(I)), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO))), SIX, ZERO)',
#  'subroutine_1 (test): downscale(I, THREE)',
#  'subroutine_0: fill(compress(I), ONE, mfilter(apply(rbind(toobject, compress(I)), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO)))',
#  'subroutine_1: downscale(replace(I, SIX, ZERO), THREE)',
#  'subroutine_0 (test): fill(compress(I), ONE, mfilter(apply(rbind(toobject, compress(I)), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO)))',
#  'subroutine_1 (test): downscale(replace(I, SIX, ZERO), THREE)',
#  'subroutine_0: fill(compress(I), ONE, mfilter(apply(rbind(toobject, compress(I)), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO)))',
#  'subroutine_1: replace(I, SIX, ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): fill(compress(I), ONE, mfilter(apply(rbind(toobject, compress(I)), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO)))',
#  'subroutine_1 (test): replace(I, SIX, ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
#  'subroutine_0: compress(I)',
#  'subroutine_1: downscale(replace(fill(I, ONE, mfilter(apply(rbind(toobject, I), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO))), SIX, ZERO), THREE)',
#  'subroutine_0 (test): compress(I)',
#  'subroutine_1 (test): downscale(replace(fill(I, ONE, mfilter(apply(rbind(toobject, I), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO))), SIX, ZERO), THREE)',
#  'subroutine_0: compress(I)',
#  'subroutine_1: replace(fill(I, ONE, mfilter(apply(rbind(toobject, I), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO))), SIX, ZERO)',
#  'subroutine_2: downscale(I, THREE)',
#  'subroutine_0 (test): compress(I)',
#  'subroutine_1 (test): replace(fill(I, ONE, mfilter(apply(rbind(toobject, I), apply(fork(insert, identity, neighbors), shift(apply(rbind(multiply, THREE), insert(ORIGIN, neighbors(ORIGIN))), astuple(FOUR, FOUR)))), matcher(rbind(colorcount, SIX), TWO))), SIX, ZERO)',
#  'subroutine_2 (test): downscale(I, THREE)',
# ...
#  'subroutine_1 (test): fill(I, TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(I, asobject(canvas(FIVE, astuple(ONE, THREE))))))',
#  'subroutine_2 (test): fill(I, TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(I, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))))',
#  'subroutine_3 (test): fill(I, TWO, mapply(lbind(shift, asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(I, asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))))',
#  'subroutine_4 (test): fill(I, TWO, mapply(lbind(shift, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), occurrences(I, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))))',
#  'subroutine_0: fill(I, EIGHT, mapply(lbind(shift, asobject(canvas(FIVE, TWO_BY_TWO))), occurrences(I, asobject(canvas(FIVE, TWO_BY_TWO)))))',
#  'subroutine_1: fill(fill(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), TWO, mapply(lbind(shift, asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), TWO, mapply(lbind(shift, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), occurrences(fill(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurr ...
#  'subroutine_0 (test): fill(I, EIGHT, mapply(lbind(shift, asobject(canvas(FIVE, TWO_BY_TWO))), occurrences(I, asobject(canvas(FIVE, TWO_BY_TWO)))))',
#  'subroutine_1 (test): fill(fill(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), TWO, mapply(lbind(shift, asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), TWO, mapply(lbind(shift, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), occurrences(fill(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), ...
#  'subroutine_0: fill(I, EIGHT, mapply(lbind(shift, asobject(canvas(FIVE, TWO_BY_TWO))), occurrences(I, asobject(canvas(FIVE, TWO_BY_TWO)))))',
#  'subroutine_1: fill(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), TWO, mapply(lbind(shift, asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))))',
#  'subroutine_2: fill(I, TWO, mapply(lbind(shift, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), occurrences(I, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))))',
#  'subroutine_0 (test): fill(I, EIGHT, mapply(lbind(shift, asobject(canvas(FIVE, TWO_BY_TWO))), occurrences(I, asobject(canvas(FIVE, TWO_BY_TWO)))))',
#  'subroutine_1 (test): fill(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), TWO, mapply(lbind(shift, asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), TWO, mapply(lbind(shift, asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))), occurrences(fill(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), TWO, mapply(lbind(shift, asobject(canvas(FIVE, astuple(ONE, THREE)))), occurrences(fill(I, TWO, mapply(lbind(shift, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))), occurrences(I, asobject(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), asobject(canvas(FIVE, astuple(ONE, THREE)))))), asobject(hmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))), asobject(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))))',
#  'subroutine_2 (test): fill(I, TWO, mapply(lbind(shift, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY)))))), occurrences(I, asobject(vmirror(dmirror(vconcat(canvas(EIGHT, astuple(TWO, ONE)), canvas(FIVE, UNITY))))))))',
#  ...]

# %%
import json

class ProgramSequenceAnalyzer:
    def __init__(self, descriptions='operation_descriptions.json'):
        with open(descriptions, 'r') as f:
            self.descriptions = json.load(f)
        self.var_references = {}  # Track where variables are first defined

    def generate_instructions(self, solver_code):
        var_descriptions = {}
        instructions = []
        step_counter = 1

        for line in solver_code:
            if '=' not in line:
                continue

            var, expr = line.strip().split('=', 1)
            var = var.strip()
            expr = expr.strip()

            func_name, args = self._parse_expression(expr)
            func_desc = self.descriptions.get(func_name, f'Perform {func_name} operation.')
            args_list = self._parse_arguments(args)

            # Create concise argument references
            arg_descs = []
            for arg in args_list:
                if arg in var_descriptions:
                    # Reference the step where this variable was defined
                    ref_step = self.var_references[arg]
                    arg_desc = f"the result from step {ref_step}"
                else:
                    arg_desc = arg
                arg_descs.append(arg_desc)

            # Build the instruction using concise references
            instruction = self._format_instruction(func_desc, arg_descs)
            
            # Store the step number where this variable is defined
            self.var_references[var] = step_counter
            var_descriptions[var] = instruction
            
            instructions.append(instruction)
            step_counter += 1

        # Format the final paragraph with proper transitions
        return self._format_paragraph(instructions)

    def _format_instruction(self, func_desc, arg_descs):
        """Format the instruction with natural language transitions."""
        # Replace placeholder arguments with actual descriptions
        for i, arg_desc in enumerate(arg_descs, 1):
            placeholder = f"{{arg{i}}}"
            func_desc = func_desc.replace(placeholder, arg_desc)
        return func_desc

    def _format_paragraph(self, instructions):
        """Format instructions into a coherent paragraph with transitions."""
        transitions = ["Step 1", "Step 2", "Step 3", "Step 4", "Step 5", "Step 6", "Step 7", "Step 8", "Step 9", "Step 10"]
        formatted_steps = []
        
        for i, instruction in enumerate(instructions):
            if i < len(transitions):
                transition = transitions[i]
            else:
                transition = "Then"
            formatted_steps.append(f"{transition}, {instruction.lower()}")
        
        return " ".join(formatted_steps) + "."

    def _parse_expression(self, expr):
        func_end = expr.find('(')
        func_name = expr[:func_end]
        args = expr[func_end + 1:-1]
        return func_name.strip(), args.strip()

    def _parse_arguments(self, args):
        args_list = []
        current_arg = ''
        paren_count = 0
        
        for char in args:
            if char == ',' and paren_count == 0:
                args_list.append(current_arg.strip())
                current_arg = ''
            else:
                current_arg += char
                if char == '(':
                    paren_count += 1
                elif char == ')':
                    paren_count -= 1
                    
        if current_arg:
            args_list.append(current_arg.strip())
        return args_list

# %%
solver_code = [
    'x1 = objects(I, T, F, T)',
    'x2 = fork(multiply, height, width)',
    'x3 = argmax(x1, x2)',
    'x4 = color(x3)',
    'O = canvas(x4, TWO_BY_TWO)'
]

analyzer = ProgramSequenceAnalyzer()
instructions = analyzer.generate_instructions(solver_code)
instructions
# Out:
# 'Step 1, find all the objects in i based on the settings: univalued=t (objects of one color), diagonal connectivity=f, and excluding background=t. it groups cells into objects accordingly. Step 2, create a new function that takes an input, applies height and width to it separately, and then applies multiply to both results. it combines the outcomes of two functions using another function. Step 3, find the element in the result from step 1 that makes the result from step 2 give the largest result. it returns that element from the result from step 1. for example, if the result from step 2 is "length", and the result from step 1 is ["apple", "banana"], it returns "banana" because it is longer. Step 4, get the color of the result from step 3. if the result from step 3 has only one color, it returns that color. Step 5, create a new grid of size two_by_two, filled entirely with the result from step 4. it’s like making a blank drawing area..'
